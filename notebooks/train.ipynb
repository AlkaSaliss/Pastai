# %%
# %config IPCompleter.use_jedi = False
from IPython.display import display, HTML

display(HTML(data="""
<style>
    div#notebook-container    { width: 99%; }
    div#menubar-container     { width: 99%; }
    div#maintoolbar-container { width: 99%; }
</style>
"""))
# Out:
# <style>
#     div#notebook-container    { width: 99%; }
#     div#menubar-container     { width: 99%; }
#     div#maintoolbar-container { width: 99%; }
# </style>

# %%
# load class names

# %%
# create data configuration file

data_config = """
# train and val data as 1) directory: path/images/, 2) file: path/images.txt, or 3) list: [path1/images/, path2/images/]
train: /data/Documents/Pastai/inputs/annotations/pastai_annotated_data_small/images/train/
val: /data/Documents/Pastai/inputs/annotations/pastai_annotated_data_small/images/val/

# number of classes
nc: 1

# class names
names: ['watermelon']
"""
with open("../inputs/annotations/pastai_annotated_data_small/pastai_data_config_small.yaml", "w") as f:
    f.writelines(data_config)

# %%
# %%time

# %cd "/usr/src/app/"

# !python train.py --img-size 640 --rect --batch 1 --epochs 100 \
    --data "/data/Documents/Pastai/inputs/annotations/pastai_annotated_data_small/pastai_data_config_small.yaml" \
    --weights yolov5s.pt \
    --cache-images \
    --device 0 \
    --multi-scale \
    --project "/data/Documents/Pastai/output/train/small/run"

# %cd "/data/Documents/Pastai/notebooks/"
# Out:
# /usr/src/app
# github: skipping check (Docker image)
# YOLOv5 🚀 v5.0-116-gaad99b6 torch 1.9.0a0+df837d0 CUDA:0 (NVIDIA GeForce GTX 1050, 4042.375MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=1, bbox_interval=-1, bucket='', cache_images=True, cfg='', data='/data/Documents/Pastai/inputs/annotations/pastai_annotated_data_small/pastai_data_config_small.yaml', device='0', entity=None, epochs=100, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=True, name='exp', noautoanchor=False, nosave=False, notest=False, project='/data/Documents/Pastai/output/train/small/run', quad=False, rect=True, resume=False, save_dir='/data/Documents/Pastai/output/train/small/run/exp', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=1, upload_dataset=False, weights='yolov5s.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir /data/Documents/Pastai/output/train/small/run', view at http://localhost:6006/
# hyperparameters: lr0=0.01, lrf=0.2, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0
# wandb: Install Weights & Biases for YOLOv5 logging with 'pip install wandb' (recommended)
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1    156928  models.common.C3                        [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  1    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model Summary: 283 layers, 7063542 parameters, 7063542 gradients, 16.4 GFLOPS
#
# Transferred 356/362 items from yolov5s.pt
# Scaled weight_decay = 0.0005
# Optimizer groups: 62 .bias, 62 conv.weight, 59 other
# train: Scanning '/data/Documents/Pastai/inputs/annotations/pastai_annotated_data
# train: Caching images (0.0GB): 100%|███████████| 16/16 [00:00<00:00, 358.22it/s]
# val: Scanning '/data/Documents/Pastai/inputs/annotations/pastai_annotated_data_s
# val: Caching images (0.0GB): 100%|█████████████| 16/16 [00:00<00:00, 535.64it/s]
# Plotting labels...
# val: Scanning '/data/Documents/Pastai/inputs/annotations/pastai_annotated_data_s
#
# autoanchor: Analyzing anchors... anchors/target = 4.24, Best Possible Recall (BPR) = 1.0000
# Image sizes 640 train, 640 test
# Using 0 dataloader workers
# Logging results to /data/Documents/Pastai/output/train/small/run/exp
# Starting training for 100 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       0/99    0.633G   0.08857   0.02371         0    0.1123         1       448/opt/conda/lib/python3.8/site-packages/torch/jit/_trace.py:727: UserWarning: The input to trace is already a ScriptModule, tracing it is a no-op. Returning the object as is.
#   warnings.warn(
#       0/99    0.648G   0.08445   0.02967         0    0.1141         2       224
#                Class      Images      Labels           P           R      mAP@.5
#                  all          16          17     0.00257       0.294    0.000885    0.000107
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       1/99    0.654G   0.08269   0.02961         0    0.1123         2       576
#                Class      Images      Labels           P           R      mAP@.5
#                  all          16          17      0.0364      0.0588     0.00402    0.000404
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       2/99    0.713G   0.07527   0.02451         0   0.09978         2       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all          16          17       0.917      0.0588      0.0731      0.0186
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       3/99    0.713G   0.08655   0.03105         0    0.1176         2       320
#                Class      Images      Labels           P           R      mAP@.5
#                  all          16          17       0.309       0.176       0.121      0.0184
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       4/99    0.724G   0.08115   0.02797         0    0.1091         2       320
#                Class      Images      Labels           P           R      mAP@.5
#                  all          16          17       0.437       0.412        0.28      0.0604
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       5/99    0.724G   0.07584    0.0306         0    0.1064         2       352
#                Class      Images      Labels           P           R      mAP@.5
#                  all          16          17        0.75       0.353       0.359       0.108
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       6/99    0.724G   0.07312   0.02991         0     0.103         1       320
#                Class      Images      Labels           P           R      mAP@.5
#                  all          16          17       0.664       0.471       0.425      0.0923
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       7/99    0.724G   0.06738   0.03068         0   0.09806         2       288
#                Class      Images      Labels           P           R      mAP@.5
#                  all          16          17       0.762       0.471       0.536       0.159
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       8/99    0.726G   0.06964   0.03062         0    0.1003         2       480
#                Class      Images      Labels           P           R      mAP@.5
#                  all          16          17       0.641       0.529       0.608       0.202
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       9/99    0.726G   0.06121   0.02959         0    0.0908         1       224
#                Class      Images      Labels           P           R      mAP@.5
#                  all          16          17       0.427       0.765       0.505       0.215
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      10/99    0.726G    0.0585   0.03284         0   0.09135         2       288
#                Class      Images      Labels           P           R      mAP@.5
#                  all          16          17       0.586       0.583       0.559       0.275
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      11/99    0.726G   0.05361   0.02829         0    0.0819         2       576
#                Class      Images      Labels           P           R      mAP@.5
#                  all          16          17       0.758       0.588       0.609       0.231
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      12/99    0.726G   0.05701   0.03374         0   0.09075         2       480
#                Class      Images      Labels           P           R      mAP@.5
#                  all          16          17       0.797       0.529       0.614        0.21
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      13/99    0.726G   0.05436   0.03772         0   0.09207         2       192
#                Class      Images      Labels           P           R      mAP@.5
#                  all          16          17       0.706       0.588       0.616       0.189
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      14/99    0.726G   0.05427   0.03173         0     0.086         1       288
#                Class      Images      Labels           P           R      mAP@.5
#                  all          16          17       0.718       0.529       0.647       0.195
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      15/
/data/Documents/Pastai/inputs/annotations/pastai_annotated_data/images/val/

# number of classes
nc: 1

# class names
names: ['watermelon']
"""
with open("../inputs/annotations/pastai_annotated_data/pastai_data_config.yaml", "w") as f:
    f.writelines(data_config)

# %%
# %%time

# %cd "/usr/src/app/"

# !python train.py --img-size 224 \
    --rect \
    --batch-size 16 \
    --epochs 100 \
    --data "/data/Documents/Pastai/inputs/annotations/pastai_annotated_data/pastai_data_config.yaml" \
    --weights yolov5s.pt \
    --cache-images \
    --device 0 \
    --project "/data/Documents/Pastai/output/train/full/"

# %cd "/data/Documents/Pastai/notebooks/"
# Out:
# /usr/src/app
# github: skipping check (Docker image)
# YOLOv5 🚀 v5.0-116-gaad99b6 torch 1.9.0a0+df837d0 CUDA:0 (NVIDIA GeForce GTX 1050, 4042.375MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=True, cfg='', data='/data/Documents/Pastai/inputs/annotations/pastai_annotated_data/pastai_data_config.yaml', device='0', entity=None, epochs=100, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[224, 224], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='exp', noautoanchor=False, nosave=False, notest=False, project='/data/Documents/Pastai/output/train/full/', quad=False, rect=True, resume=False, save_dir='/data/Documents/Pastai/output/train/full/exp', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='yolov5s.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir /data/Documents/Pastai/output/train/full/', view at http://localhost:6006/
# hyperparameters: lr0=0.01, lrf=0.2, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0
# wandb: Install Weights & Biases for YOLOv5 logging with 'pip install wandb' (recommended)
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1    156928  models.common.C3                        [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  1    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model Summary: 283 layers, 7063542 parameters, 7063542 gradients, 16.4 GFLOPS
#
# Transferred 356/362 items from yolov5s.pt
# Scaled weight_decay = 0.0005
# Optimizer groups: 62 .bias, 62 conv.weight, 59 other
# train: Scanning '/data/Documents/Pastai/inputs/annotations/pastai_annotated_data
# train: New cache created: /data/Documents/Pastai/inputs/annotations/pastai_annotated_data/labels/train.cache
# train: Caching images (0.3GB): 100%|████████| 3984/3984 [00:39<00:00, 99.61it/s]
# val: Scanning '/data/Documents/Pastai/inputs/annotations/pastai_annotated_data/l
# val: New cache created: /data/Documents/Pastai/inputs/annotations/pastai_annotated_data/labels/val.cache
# val: Caching images (0.1GB): 100%|████████████| 704/704 [00:07<00:00, 92.62it/s]
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 5.36, Best Possible Recall (BPR) = 1.0000
# Image sizes 224 train, 224 test
# Using 8 dataloader workers
# Logging results to /data/Documents/Pastai/output/train/full/exp
# Starting training for 100 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       0/99     1.46G     0.116   0.01239         0    0.1284        16       128/opt/conda/lib/python3.8/site-packages/torch/jit/_trace.py:727: UserWarning: The input to trace is already a ScriptModule, tracing it is a no-op. Returning the object as is.
#   warnings.warn(
#       0/99     1.54G    0.0886   0.02106         0    0.1097        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.356       0.355       0.271      0.0714
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       1/99     1.54G   0.05983   0.01987         0   0.07971        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.578       0.498       0.447       0.166
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       2/99     1.54G   0.05603   0.02025         0   0.07628        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.648       0.569       0.548       0.183
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       3/99     1.54G   0.05404   0.02007         0   0.07411        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.469       0.433       0.371       0.122
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       4/99     1.54G   0.05277   0.02045         0   0.07323        19       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435        0.57       0.526       0.497       0.181
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       5/99     1.54G   0.05096   0.02026         0   0.07121        18       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.691       0.609       0.646       0.294
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       6/99     1.54G   0.04589   0.01964         0   0.06553        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435        0.76       0.568       0.655       0.273
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       7/99     1.54G   0.04502   0.01867         0   0.06369        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.858       0.647       0.755       0.321
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       8/99     1.54G   0.04351   0.01785         0   0.06136        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.816       0.723        0.78       0.367
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       9/99     1.54G   0.04196   0.01786         0   0.05982        18       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.782       0.664       0.717        0.32
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      10/99     1.54G    0.0406    0.0172         0    0.0578        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.818       0.679       0.754       0.321
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      11/99     1.54G   0.03969   0.01689         0   0.05658        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.781       0.701        0.75       0.348
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      12/99     1.54G   0.03968   0.01666         0   0.05634        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435        0.87       0.731       0.815       0.382
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      13/99     1.54G   0.03806   0.01587         0   0.05393        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.856        0.81       0.858       0.414
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      14/99     1.54G   0.03664   0.01544         0   0.05207        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.887       0.791       0.852       0.409
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      15/99     1.54G   0.03623   0.01538         0   0.05161        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.874       0.794       0.859       0.414
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      16/99     1.54G   0.03568   0.01483         0   0.05051        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.896       0.803       0.868       0.421
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      17/99     1.54G   0.03525   0.01484         0   0.05009        19       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.877       0.721       0.816       0.382
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      18/99     1.54G   0.03471    0.0147         0   0.04942        19       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.917       0.808       0.885       0.404
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      19/99     1.54G   0.03381   0.01436         0   0.04816        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.883       0.832       0.897       0.451
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      20/99     1.54G   0.03503   0.01428         0   0.04931        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.852       0.826       0.872       0.412
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      21/99     1.54G   0.03315   0.01397         0   0.04712        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0
data/Documents/Pastai/inputs/annotations/pastai_annotated_data/pastai_data_config.yaml" \
    --weights yolov5m.pt \
    --cache-images \
    --device 0 \
    --project "/data/Documents/Pastai/output/train/full/"

# %cd "/data/Documents/Pastai/notebooks/"
# Out:
# /usr/src/app
# github: skipping check (Docker image)
# YOLOv5 🚀 v5.0-116-gaad99b6 torch 1.9.0a0+df837d0 CUDA:0 (NVIDIA GeForce GTX 1050, 4042.375MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=32, bbox_interval=-1, bucket='', cache_images=True, cfg='', data='/data/Documents/Pastai/inputs/annotations/pastai_annotated_data/pastai_data_config.yaml', device='0', entity=None, epochs=100, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[224, 224], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='exp', noautoanchor=False, nosave=False, notest=False, project='/data/Documents/Pastai/output/train/full/', quad=False, rect=True, resume=False, save_dir='/data/Documents/Pastai/output/train/full/exp2', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=32, upload_dataset=False, weights='yolov5m.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir /data/Documents/Pastai/output/train/full/', view at http://localhost:6006/
# hyperparameters: lr0=0.01, lrf=0.2, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0
# wandb: Install Weights & Biases for YOLOv5 logging with 'pip install wandb' (recommended)
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      5280  models.common.Focus                     [3, 48, 3]
#   1                -1  1     41664  models.common.Conv                      [48, 96, 3, 2]
#   2                -1  1     65280  models.common.C3                        [96, 96, 2]
#   3                -1  1    166272  models.common.Conv                      [96, 192, 3, 2]
#   4                -1  1    629760  models.common.C3                        [192, 192, 6]
#   5                -1  1    664320  models.common.Conv                      [192, 384, 3, 2]
#   6                -1  1   2512896  models.common.C3                        [384, 384, 6]
#   7                -1  1   2655744  models.common.Conv                      [384, 768, 3, 2]
#   8                -1  1   1476864  models.common.SPP                       [768, 768, [5, 9, 13]]
#   9                -1  1   4134912  models.common.C3                        [768, 768, 2, False]
#  10                -1  1    295680  models.common.Conv                      [768, 384, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1   1182720  models.common.C3                        [768, 384, 2, False]
#  14                -1  1     74112  models.common.Conv                      [384, 192, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1    296448  models.common.C3                        [384, 192, 2, False]
#  18                -1  1    332160  models.common.Conv                      [192, 192, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1   1035264  models.common.C3                        [384, 384, 2, False]
#  21                -1  1   1327872  models.common.Conv                      [384, 384, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   4134912  models.common.C3                        [768, 768, 2, False]
#  24      [17, 20, 23]  1     24246  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [192, 384, 768]]
# Model Summary: 391 layers, 21056406 parameters, 21056406 gradients, 50.4 GFLOPS
#
# Transferred 500/506 items from yolov5m.pt
# Scaled weight_decay = 0.0005
# Optimizer groups: 86 .bias, 86 conv.weight, 83 other
# train: Scanning '/data/Documents/Pastai/inputs/annotations/pastai_annotated_data
# train: Caching images (0.3GB): 100%|███████| 3984/3984 [00:10<00:00, 368.59it/s]
# val: Scanning '/data/Documents/Pastai/inputs/annotations/pastai_annotated_data/l
# val: Caching images (0.1GB): 100%|███████████| 704/704 [00:02<00:00, 316.47it/s]
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 5.36, Best Possible Recall (BPR) = 1.0000
# Image sizes 224 train, 224 test
# Using 8 dataloader workers
# Logging results to /data/Documents/Pastai/output/train/full/exp2
# Starting training for 100 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       0/99     2.12G    0.1205   0.01232         0    0.1328        38       128/opt/conda/lib/python3.8/site-packages/torch/jit/_trace.py:727: UserWarning: The input to trace is already a ScriptModule, tracing it is a no-op. Returning the object as is.
#   warnings.warn(
#       0/99     2.14G   0.09537   0.02253         0    0.1179        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.418       0.351       0.305      0.0844
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       1/99     2.19G   0.06164    0.0204         0   0.08204        19       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.695       0.677       0.679       0.287
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       2/99     2.19G   0.05191   0.01868         0   0.07059        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435         0.8       0.769       0.771       0.342
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       3/99     2.19G   0.04639   0.01758         0   0.06397        18       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.835       0.756       0.809       0.404
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       4/99     2.19G   0.05026    0.0176         0   0.06786        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.713       0.605       0.649       0.297
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       5/99     2.19G   0.04656   0.01766         0   0.06421        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.814       0.741       0.789       0.304
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       6/99     2.19G    0.0456   0.01737         0   0.06297        18       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.758       0.576       0.648       0.318
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       7/99     2.19G   0.04441   0.01786         0   0.06227        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.681       0.564       0.612       0.256
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       8/99     2.19G    0.0458   0.01889         0   0.06469        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.726       0.508        0.57       0.269
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       9/99     2.19G   0.04661   0.02003         0   0.06665        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.634       0.498       0.547       0.216
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      10/99     2.19G   0.04545   0.01873         0   0.06418        19       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.688       0.476       0.535       0.227
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      11/99     2.19G   0.04206   0.01782         0   0.05988        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.812       0.725       0.783       0.364
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      12/99     2.19G   0.04008   0.01672         0    0.0568        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.891       0.782       0.836       0.418
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      13/99     2.19G   0.03747   0.01582         0   0.05329        18       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.913       0.794       0.865       0.422
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      14/99     2.19G   0.03587   0.01501         0   0.05088        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.909       0.813       0.894        0.46
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      15/99     2.19G   0.03457   0.01462         0   0.04919        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.911       0.811       0.894       0.464
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      16/99     2.19G   0.03427     0.014         0   0.04827        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.883       0.838       0.879       0.448
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      17/99     2.19G   0.03319   0.01384         0   0.04702        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.893       0.865       0.908        0.45
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      18/99     2.19G   0.03356   0.01375         0   0.04731        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435       0.911       0.828       0.898       0.445
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      19/99     2.19G   0.03255    0.0133         0   0.04585        20       128
#                Class      Images      Labels           P           R      mAP@.5
#                  all         704        1435        0
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break
    img = Image.fromarray(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    preds = predict(model, img, conf_thres, iou_thres)
    img = np.array(img.resize((IMG_SIZE, IMG_SIZE)))
    img = post_process_img(img, preds)
    st.image(Image.fromarray(img), width=512)

# %%
onnx_model_small = onnx.load("../output/yolo_colab/exp3/weights/best.onnx")
sess = onnx_rt.InferenceSession("../output/yolo_colab/exp3/weights/best.onnx")

# %%
# %%time
for _ in range(100):
    pred_onnx = sess.run(None, {"images": np.zeros((1, 3, 256,256)).astype(np.float32)})[0]
# Out:
# CPU times: user 6.48 s, sys: 0 ns, total: 6.48 s
# Wall time: 1.62 s

# %%
pred_onnx.shape
# Out:
# (1, 4032, 6)

# %%
model = torch.load("../output/yolo_colab/exp3/weights/best.pt")["model"].float().eval()

# %%
x = np.array(Image.open("../inputs/annotations/pastai_annotated_data_small/images/train/frame_000000.jpg").resize((256,256)))
x = torch.tensor(x.transpose((2, 0, 1))/255.).unsqueeze(0).float()

# %%
# %%time
for _ in range(100):
    with torch.no_grad():
        pred = model(x)
# Out:
# CPU times: user 13.1 s, sys: 0 ns, total: 13.1 s
# Wall time: 3.28 s

# %%
pred[0].shape
# Out:
# torch.Size([1, 4032, 6])

# %%
pred_bis = [item.numpy() for item in non_max_suppression(pred[0])]

# %%
pred_bis[0]
# Out:
# array([[     58.322,      75.386,      170.23,      162.68,     0.75411,           0]], dtype=float32)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x_im = np.array(Image.open("../inputs/annotations/pastai_annotated_data_small/images/train/frame_000000.jpg").resize((256,256)))
tmp = cv2.rectangle(x_im, (int(pred_bis[0][0][0]), int(pred_bis[0][0][1])), (int(pred_bis[0][0][2]), int(pred_bis[0][0][3])), (255, 0,0))
plt.imshow(x_im)
plt.show()

# %%
plt.imshow(tmp)

# %%
Image.open("../inputs/annotations/pastai_annotated_data_small/images/train/frame_000000.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x1280 at 0x7F6FD8496910>

# %%
def xywh2xyxy(x):
    # Convert nx4 boxes from [x, y, w, h] to [x1, y1, x2, y2] where xy1=top-left, xy2=bottom-right
    y = x.clone() if isinstance(x, torch.Tensor) else np.copy(x)
    y[:, 0] = x[:, 0] - x[:, 2] / 2  # top left x
    y[:, 1] = x[:, 1] - x[:, 3] / 2  # top left y
    y[:, 2] = x[:, 0] + x[:, 2] / 2  # bottom right x
    y[:, 3] = x[:, 1] + x[:, 3] / 2  # bottom right y
    return y


def non_max_suppression(prediction, conf_thres=0.25, iou_thres=0.45, classes=None, agnostic=False, multi_label=False,
                        labels=(), max_det=300):
    """Runs Non-Maximum Suppression (NMS) on inference results
    Returns:
         list of detections, on (n,6) tensor per image [xyxy, conf, cls]
    """

    nc = prediction.shape[2] - 5  # number of classes
    xc = prediction[..., 4] > conf_thres  # candidates

    # Checks
    assert 0 <= conf_thres <= 1, f'Invalid Confidence threshold {conf_thres}, valid values are between 0.0 and 1.0'
    assert 0 <= iou_thres <= 1, f'Invalid IoU {iou_thres}, valid values are between 0.0 and 1.0'

    # Settings
    min_wh, max_wh = 2, 4096  # (pixels) minimum and maximum box width and height
    max_nms = 30000  # maximum number of boxes into torchvision.ops.nms()
    time_limit = 10.0  # seconds to quit after
    redundant = True  # require redundant detections
    multi_label &= nc > 1  # multiple labels per box (adds 0.5ms/img)
    merge = False  # use merge-NMS

    t = time.time()
    output = [torch.zeros((0, 6), device=prediction.device)] * prediction.shape[0]
    for xi, x in enumerate(prediction):  # image index, image inference
        # Apply constraints
        # x[((x[..., 2:4] < min_wh) | (x[..., 2:4] > max_wh)).any(1), 4] = 0  # width-height
        x = x[xc[xi]]  # confidence

        # Cat apriori labels if autolabelling
        if labels and len(labels[xi]):
            l = labels[xi]
            v = torch.zeros((len(l), nc + 5), device=x.device)
            v[:, :4] = l[:, 1:5]  # box
            v[:, 4] = 1.0  # conf
            v[range(len(l)), l[:, 0].long() + 5] = 1.0  # cls
            x = torch.cat((x, v), 0)

        # If none remain process next image
        if not x.shape[0]:
            continue

        # Compute conf
        x[:, 5:] *= x[:, 4:5]  # conf = obj_conf * cls_conf

        # Box (center x, center y, width, height) to (x1, y1, x2, y2)
        box = xywh2xyxy(x[:, :4])

        # Detections matrix nx6 (xyxy, conf, cls)
        if multi_label:
            i, j = (x[:, 5:] > conf_thres).nonzero(as_tuple=False).T
            x = torch.cat((box[i], x[i, j + 5, None], j[:, None].float()), 1)
        else:  # best class only
            conf, j = x[:, 5:].max(1, keepdim=True)
            x = torch.cat((box, conf, j.float()), 1)[conf.view(-1) > conf_thres]

        # Filter by class
        if classes is not None:
            x = x[(x[:, 5:6] == torch.tensor(classes, device=x.device)).any(1)]

        # Apply finite constraint
        # if not torch.isfinite(x).all():
        #     x = x[torch.isfinite(x).all(1)]

        # Check shape
        n = x.shape[0]  # number of boxes
        if not n:  # no boxes
            continue
        elif n > max_nms:  # excess boxes
            x = x[x[:, 4].argsort(descending=True)[:max_nms]]  # sort by confidence

        # Batched NMS
        c = x[:, 5:6] * (0 if agnostic else max_wh)  # classes
        boxes, scores = x[:, :4] + c, x[:, 4]  # boxes (offset by class), scores
        i = torchvision.ops.nms(boxes, scores, iou_thres)  # NMS
        if i.shape[0] > max_det:  # limit detections
            i = i[:max_det]
        if merge and (1 < n < 3E3):  # Merge NMS (boxes merged using weighted mean)
            # update boxes as boxes(i,4) = weights(i,n) * boxes(n,4)
            iou = box_iou(boxes[i], boxes) > iou_thres  # iou matrix
            weights = iou * scores[None]  # box weights
            x[i, :4] = torch.mm(weights, x[:, :4]).float() / weights.sum(1, keepdim=True)  # merged boxes
            if redundant:
                i = i[iou.sum(1) > 1]  # require redundancy

        output[xi] = x[i]
        if (time.time() - t) > time_limit:
            print(f'WARNING: NMS time limit {time_limit}s exceeded')
            break  # time limit exceeded

    return output

# %%
tmp = np.arange(3).reshape(3, 1)
tmp
# Out:
# array([[0],
#        [1],
#        [2]])

# %%
tmp.squeeze()
# Out:
# array([0, 1, 2])

# %%
cv2.__version__
# Out:
# '4.5.2'
